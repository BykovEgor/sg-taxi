# %%
import pandas as pd
import numpy as np

# %%
data_pd = pd.read_csv('SGHitch_msg.csv')

# %%
data_pd.head()
# Out:
#                         date  mess_id    user_id          username    bot  \
# 0  2019-02-25 17:32:20+00:00        1  587793322  jyjyjyjyjyjyjyjy  False
# 1  2019-10-12 16:00:55+00:00   463142  360992588         cssksskyy  False
# 2  2019-10-12 16:01:02+00:00   463143   40672545        jacindakyt  False
# 3  2019-10-12 16:01:09+00:00   463145  152253888               NaN  False
# 4  2019-10-12 16:01:14+00:00   463146   47916066         SiangFong  False
#
#    deleted                           action  \
# 0    False  MessageActionChannelMigrateFrom
# 1    False                              NaN
# 2    False                              NaN
# 3    False                              NaN
# 4    False                              NaN
#
#                                             act_entr  \
# 0  [{'ChatForbidden': {'title': 'SG Hitch', 'id':...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
data_pd.tail()
# Out:
#                             date  mess_id    user_id      username    bot  \
# 40182  2019-10-28 05:04:43+00:00   512302  208306434           NaN  False
# 40183  2019-10-28 05:04:54+00:00   512303   34644314     tanshihui  False
# 40184  2019-10-28 05:05:58+00:00   512304  238280875  jeremyee1996  False
# 40185  2019-10-28 05:06:01+00:00   512305  327527914      Xuan0305  False
# 40186  2019-10-28 05:06:02+00:00   512306  883368419    SGHitchBot   True
#
#        deleted action act_entr  \
# 40182    False    NaN      NaN
# 40183    False    NaN      NaN
# 40184    False    NaN      NaN
# 40185    False    NaN      NaN
# 40186    False    NaN      NaN
#
#                                                  message  reply_to_msg_id  \
# 40182  👋🏻 Hitcher looking for Drivers\nPick up: eunos...              NaN
# 40183  🚗 Driver looking for Hitchers\nPick Up: Parkwa...              NaN
# 40184  👋🏻 Hitcher looking for Drivers\nPick up: yio c...              NaN
# ...
